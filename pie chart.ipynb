# %%
import csv
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
filepath_t = os.path.join("temperature.csv")
filepath_traf = os.path.join("Traffic_Collision_Data_from_2010_to_Present.csv")
filepath_w = os.path.join("weather_description.csv")

# %%
temperature = pd.read_csv(filepath_t)
weather = pd.read_csv(filepath_w)
traffic = pd.read_csv(filepath_traf)

# %%
weather_LA = weather[['datetime','Los Angeles']]
weather_breakdown = weather_LA['Los Angeles'].value_counts()
weather_pie_list = weather_breakdown[:11]
weather_pie_list
labels = ["sky is clear","haze","mist",\
          "broken clouds","overcast clouds",\
          "scattered clouds","light rain","few clouds",\
          "fog","moderate rain","smoke"]
colors = ["lightseagreen","mediumaquamarine","springgreen","limegreen","gold",\
         "orange", "coral", "tomato", "red",\
         "firebrick","gold"]
explode = (0.03, 0.03, 0.03, 0.03, 0.03, 0.03,0.15,0.03,0.03,0.15,0.03)

plt.pie(weather_pie_list,labels = labels,shadow=True,autopct="%1.1f%%",labeldistance=1.5,\
        colors=colors,startangle=170,pctdistance=1.35,explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x12f0689b0>,
#   <matplotlib.patches.Wedge at 0x12f070438>,
#   <matplotlib.patches.Wedge at 0x12f070eb8>,
#   <matplotlib.patches.Wedge at 0x12f105978>,
#   <matplotlib.patches.Wedge at 0x12f111438>,
#   <matplotlib.patches.Wedge at 0x12f111eb8>,
#   <matplotlib.patches.Wedge at 0x12f11b978>,
#   <matplotlib.patches.Wedge at 0x12f124438>,
#   <matplotlib.patches.Wedge at 0x12f124eb8>,
#   <matplotlib.patches.Wedge at 0x12f12c978>,
#   <matplotlib.patches.Wedge at 0x12f135438>],
#  [Text(0.130332,-1.52444,'sky is clear'),
#   Text(1.26921,0.854404,'haze'),
#   Text(0.764892,1.32508,'mist'),
#   Text(0.208144,1.51578,'broken clouds'),
#   Text(-0.324231,1.49525,'overcast clouds'),
#   Text(-0.790485,1.30997,'scattered clouds'),
#   Text(-1.22703,1.10313,'light rain'),
#   Text(-1.36222,0.696599,'few clouds'),
#   Text(-1.45707,0.466731,'fog'),
#   Text(-1.60401,0.386855,'moderate rain'),
#   Text(-1.50283,0.287078,'smoke')],
#  [Text(0.117554,-1.37498,'58.3%'),
#   Text(1.14478,0.770639,'7.9%'),
#   Text(0.689903,1.19517,'6.6%'),
#   Text(0.187738,1.36717,'5.7%'),
#   Text(-0.292443,1.34866,'5.4%'),
#   Text(-0.712987,1.18155,'5.1%'),
#   Text(-1.11548,1.00285,'4.3%'),
#   Text(-1.22867,0.628305,'3.9%'),
#   Text(-1.31422,0.420973,'1.3%'),
#   Text(-1.45819,0.351686,'1.1%'),
#   Text(-1.35549,0.258933,'0.5%')])

# %%
traffic.head()

# %%
plt.bar(traffic
