# %%
import csv
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
filepath_t = os.path.join("temperature.csv")
filepath_traf = os.path.join("Traffic_Collision_Data_from_2010_to_Present.csv")
filepath_w = os.path.join("weather_description.csv")

# %%
temperature = pd.read_csv(filepath_t)
weather = pd.read_csv(filepath_w)
traffic = pd.read_csv(filepath_traf)

# %%
weather_LA = weather[['datetime','Los Angeles']]
weather_breakdown = weather_LA['Los Angeles'].value_counts()
weather_pie_list = weather_breakdown[:11]
# Out:
# sky is clear        26136
# haze                 3532
# mist                 2961
# broken clouds        2565
# overcast clouds      2432
# scattered clouds     2271
# light rain           1949
# few clouds           1757
# fog                   566
# moderate rain         481
# smoke                 203
# Name: Los Angeles, dtype: int64

# %%
x[1]
# Out:
# '(34.2012, -118.4662)'

# %%
coordinates = traffic['Location'].str.strip('()')                               \
                   .str.split(', ', expand=True)                   \
                   .rename(columns={0:'Latitude', 1:'Longitude'})
traffic['Lat']=coordinates['Latitude']
traffic['Long']=coordinates['Longitude']
traffic.head()
# Out:
#    DR Number   Date Reported Date Occurred  Time Occurred  Area ID  \
# 0  100119684  01/01/11042010    11/04/2010           1345        1
# 1  101221255   01/01/8102010    08/10/2010           1900       12
# 2  101414426   01/01/6112010    06/09/2010           1925       14
# 3  102109168   01/01/4062010    04/06/2010           1445       21
# 4  100322445   01/01/9222010    05/23/2010           1805        3
#
#      Area Name  Reporting District  Crime Code Crime Code Description  \
# 0      Central                 159         997      TRAFFIC COLLISION
# 1  77th Street                1211         997      TRAFFIC COLLISION
# 2      Pacific                1488         997      TRAFFIC COLLISION
# 3      Topanga                2197         997      TRAFFIC COLLISION
# 4    Southwest                 397         997      TRAFFIC COLLISION
#
#   MO Codes  Victim Age Victim Sex Victim Descent  Premise Code  \
# 0      NaN        20.0          F              H         101.0
# ...

# %%
traffic['Crime Code Description'].value_counts()
# Out:
# TRAFFIC COLLISION    432962
# Name: Crime Code Description, dtype: int64

# %%
weather_LA
# Out:
#                   datetime       Los Angeles
# 0      2012-10-01 12:00:00               NaN
# 1      2012-10-01 13:00:00              mist
# 2      2012-10-01 14:00:00      sky is clear
# 3      2012-10-01 15:00:00      sky is clear
# 4      2012-10-01 16:00:00      sky is clear
# 5      2012-10-01 17:00:00      sky is clear
# 6      2012-10-01 18:00:00      sky is clear
# 7      2012-10-01 19:00:00      sky is clear
# 8      2012-10-01 20:00:00      sky is clear
# 9      2012-10-01 21:00:00      sky is clear
# 10     2012-10-01 22:00:00      sky is clear
# 11     2012-10-01 23:00:00      sky is clear
# 12     2012-10-02 00:00:00      sky is clear
# 13     2012-10-02 01:00:00      sky is clear
# 14     2012-10-02 02:00:00      sky is clear
# 15     2012-10-02 03:00:00      sky is clear
# 16     2012-10-02 04:00:00      sky is clear
# 17     2012-10-02 05:00:00      sky is clear
# 18     2012-10-02 06:00:00      sky is clear
# 19     2012-10-02 07:00:00      sky is clear
# ...

# %%
import folium
 
# Make a data frame with dots to show on the map
data = pd.DataFrame({
   'lat':traffic['Lat'],
   'lon':traffic['Long'],
   'value':1
})
data
 
# Make an empty map
m = folium.Map(location=[20,0], tiles="Mapbox Bright", zoom_start=2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-121-dc8a494ed1e2> in <module>()
# ----> 1 import folium
#       2
#       3 # Make a data frame with dots to show on the map
#       4 data = pd.DataFrame({
#       5    'lat':traffic['Lat'],
#
# ModuleNotFoundError: No module named 'folium'

# %%
from mpl_toolkits.basemap import Basemap
import numpy as np
import matplotlib.pyplot as plt
 
# Make a data frame with the GPS of a few cities:
data = pd.DataFrame({
'lat':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
'lon':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
'name':['Buenos Aires', 'Paris', 'melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador']
})
 
# A basic map
m=Basemap(llcrnrlon=-160, llcrnrlat=-75,urcrnrlon=160,urcrnrlat=80)
m.drawmapboundary(fill_color='#A6CAE0', linewidth=0)
m.fillcontinents(color='grey', alpha=0.7, lake_color='grey')
m.drawcoastlines(linewidth=0.1, color="white")
 
# Add a marker per city of the data frame!
m.plot(data['lat'], data['lon'], linestyle='none', marker="o", markersize=16, alpha=0.6, c="orange", markeredgecolor="black", markeredgewidth=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-123-84da632940b7> in <module>()
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4
#       5 # Make a data frame with the GPS of a few cities:
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'
